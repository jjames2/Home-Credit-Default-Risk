# %%
import mitosheet

# %%
mitosheet.sheet()
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-2ac6c6c6-b386-41d5-b4aa-e2ddcd44d250", "code": {"imports…

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-2ac6c6c6-b386-41d5-b4aa-e2ddcd44d250') # Let Mito know which analysis is being run

# Imported D:\workspace\Home-Credit-Default-Risk\DATA\final_dataset.csv
import pandas as pd
final_dataset_csv = pd.read_csv(r'D:\workspace\Home-Credit-Default-Risk\DATA\final_dataset.csv')

# Pivoted final_dataset_csv into df2
unused_columns = final_dataset_csv.columns.difference(set(['CODE_GENDER']).union(set([])).union(set({'TARGET'})))
tmp_df = final_dataset_csv.drop(unused_columns, axis=1)
pivot_table = tmp_df.pivot_table(
    index=['CODE_GENDER'],
    values=['TARGET'],
    aggfunc={'TARGET': ['mean']}
)

# Flatten the column headers
pivot_table.columns = [flatten_column_header(col) for col in pivot_table.columns.values]

# Reset the column name and the indexes
df2 = pivot_table.reset_index()

# Pivoted final_dataset_csv into df3
unused_columns = final_dataset_csv.columns.difference(set(['EXT_SOURCE_1']).union(set(['TARGET'])).union(set({'TARGET'})))
tmp_df = final_dataset_csv.drop(unused_columns, axis=1)
pivot_table = tmp_df.pivot_table(
    index=['EXT_SOURCE_1'],
    columns=['TARGET'],
    values=['TARGET'],
    aggfunc={'TARGET': ['mean']}
)

# Flatten the column headers
pivot_table.columns = [flatten_column_header(col) for col in pivot_table.columns.values]

# Reset the column name and the indexes
df3 = pivot_table.reset_index()

# Added column new-column-oyel to df3
df3.insert(1, 'new-column-oyel', 0)

# Deleted dataframe df3
del df3

# Added column new-column-mlqe to final_dataset_csv
final_dataset_csv.insert(41, 'new-column-mlqe', 0)

# Added column new-column-qi7h to final_dataset_csv
final_dataset_csv.insert(41, 'new-column-qi7h', 0)

# Deleted column(s) new-column-qi7h from final_dataset_csv
final_dataset_csv.drop(['new-column-qi7h'], axis=1, inplace=True)

# Deleted column(s) new-column-mlqe from final_dataset_csv
final_dataset_csv.drop(['new-column-mlqe'], axis=1, inplace=True)

# Added column new-column-u0tc to final_dataset_csv
final_dataset_csv.insert(41, 'new-column-u0tc', 0)

# Deleted column(s) new-column-u0tc from final_dataset_csv
final_dataset_csv.drop(['new-column-u0tc'], axis=1, inplace=True)

# Pivoted final_dataset_csv into df3
unused_columns = final_dataset_csv.columns.difference(set(['TARGET']).union(set([])).union(set({'EXT_SOURCE_2', 'DEFAULT_COUNT', 'AMT_INCOME_TOTAL', 'AMT_REQ_CREDIT_BUREAU', 'EXT_SOURCE_3', 'EXT_SOURCE_1', 'AMT_CREDIT'})))
tmp_df = final_dataset_csv.drop(unused_columns, axis=1)
pivot_table = tmp_df.pivot_table(
    index=['TARGET'],
    values=['AMT_INCOME_TOTAL', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'AMT_CREDIT', 'DEFAULT_COUNT', 'AMT_REQ_CREDIT_BUREAU'],
    aggfunc={'AMT_INCOME_TOTAL': ['mean'], 'EXT_SOURCE_1': ['mean'], 'EXT_SOURCE_2': ['mean'], 'EXT_SOURCE_3': ['mean'], 'AMT_CREDIT': ['mean'], 'DEFAULT_COUNT': ['mean'], 'AMT_REQ_CREDIT_BUREAU': ['mean']}
)

# Flatten the column headers
pivot_table.columns = [flatten_column_header(col) for col in pivot_table.columns.values]

# Reset the column name and the indexes
df3 = pivot_table.reset_index()

# Pivoted final_dataset_csv into df4
unused_columns = final_dataset_csv.columns.difference(set(['CNT_CHILDREN']).union(set([])).union(set({'TARGET'})))
tmp_df = final_dataset_csv.drop(unused_columns, axis=1)
pivot_table = tmp_df.pivot_table(
    index=['CNT_CHILDREN'],
    values=['TARGET'],
    aggfunc={'TARGET': ['count', 'mean']}
)

# Flatten the column headers
pivot_table.columns = [flatten_column_header(col) for col in pivot_table.columns.values]

# Reset the column name and the indexes
df4 = pivot_table.reset_index()

# Filtered CNT_CHILDREN in df4
df4 = df4[df4['CNT_CHILDREN'] < 4]

# Pivoted final_dataset_csv into df5
unused_columns = final_dataset_csv.columns.difference(set(['NAME_EDUCATION_TYPE']).union(set([])).union(set({'TARGET'})))
tmp_df = final_dataset_csv.drop(unused_columns, axis=1)
pivot_table = tmp_df.pivot_table(
    index=['NAME_EDUCATION_TYPE'],
    values=['TARGET'],
    aggfunc={'TARGET': ['count', 'mean']}
)

# Flatten the column headers
pivot_table.columns = [flatten_column_header(col) for col in pivot_table.columns.values]

# Reset the column name and the indexes
df5 = pivot_table.reset_index()

# Filtered TARGET count in df5
df5 = df5[df5['TARGET count'] > 1000]

# Pivoted final_dataset_csv into df6
unused_columns = final_dataset_csv.columns.difference(set(['OCCUPATION_TYPE']).union(set([])).union(set({'TARGET'})))
tmp_df = final_dataset_csv.drop(unused_columns, axis=1)
pivot_table = tmp_df.pivot_table(
    index=['OCCUPATION_TYPE'],
    values=['TARGET'],
    aggfunc={'TARGET': ['count', 'mean']}
)

# Flatten the column headers
pivot_table.columns = [flatten_column_header(col) for col in pivot_table.columns.values]

# Reset the column name and the indexes
df6 = pivot_table.reset_index()

# Filtered TARGET count in df6
df6 = df6[df6['TARGET count'] > 3000]

# Sorted TARGET mean in df6 in descending order
df6 = df6.sort_values(by='TARGET mean', ascending=False, na_position='last')

  
# MITO CODE END (DO NOT EDIT)
